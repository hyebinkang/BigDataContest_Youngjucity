# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df1 = pd.read_csv('여가생활_만족도_및_불만족_이유_20240417195204_영주시 2022_KOSIS.csv',encoding='cp949')
df2 = pd.read_csv('여가생활_만족도_및_불만족_이유_20240417204725_안동시 2022_KOSIS.csv',encoding='cp949')

# %%
# 첫 번째 행을 열 이름으로 설정하고 기존의 열 이름은 삭제
df1.columns = df1.iloc[0]
df1 = df1.drop(0)

# 데이터프레임의 인덱스를 재설정 (기존 인덱스는 삭제)
df1 = df1.reset_index(drop=True)

# 첫 번째 행을 열 이름으로 설정하고 기존의 열 이름은 삭제
df2.columns = df2.iloc[0]
df2 = df2.drop(0)

# 데이터프레임의 인덱스를 재설정 (기존 인덱스는 삭제)
df2 = df2.reset_index(drop=True)

# %%
df1
# Out:
# 0     특성별(1)        특성별(2) 문화여가시설(접근성과 충분정도) 문화여가시설(접근성과 충분정도)  \
# 0     특성별(1)        특성별(2)        매우 불만족 (%)        약간 불만족 (%)
# 1         전체            소계               4.8              30.6
# 2         성별            남자               6.1              32.5
# 3         성별            여자               3.5              28.7
# 4        연령별         29세이하               6.2              41.1
# 5        연령별      30 ~ 39세               7.7              30.3
# 6        연령별      40 ~ 49세               7.8              27.5
# 7        연령별      50 ~ 59세               4.9              29.4
# 8        연령별      60 ~ 69세               1.4              27.8
# 9        연령별         70세이상               3.9              29.5
# 10  경제활동 상태별           취업자               4.6              30.9
# 11  경제활동 상태별         비경제활동               5.0              30.2
# 12     소득수준별      100만원 미만               3.6              33.7
# 13     소득수준별  100~200만원 미만               1.5              37.5
# ...

# %%
df2
# Out:
# 0     특성별(1)        특성별(2) 문화여가시설(접근성과 충분정도) 문화여가시설(접근성과 충분정도)  \
# 0     특성별(1)        특성별(2)        매우 불만족 (%)        약간 불만족 (%)
# 1         전체            소계               6.6              24.8
# 2         성별            남자               7.1              23.8
# 3         성별            여자               6.0              25.7
# 4        연령별         29세이하               6.4              22.8
# 5        연령별      30 ~ 39세               9.4              26.4
# 6        연령별      40 ~ 49세               6.6              26.9
# 7        연령별      50 ~ 59세               4.7              20.6
# 8        연령별      60 ~ 69세               5.9              24.6
# 9        연령별         70세이상               7.5              27.8
# 10  경제활동 상태별           취업자               5.3              24.0
# 11  경제활동 상태별         비경제활동               8.5              25.9
# 12     소득수준별      100만원 미만              10.4              28.6
# 13     소득수준별  100~200만원 미만               5.7              21.6
# ...

# %%
facility_youngju = df1[['특성별(1)', '특성별(2)', '문화여가시설(접근성과 충분정도)']]
facility_youngju

# 첫 번째 행을 열 이름으로 설정하고 기존의 열 이름은 삭제
facility_youngju.columns = facility_youngju.iloc[0]
facility_youngju = facility_youngju.drop(0)

# 데이터프레임의 인덱스를 재설정 (기존 인덱스는 삭제)
facility_youngju = facility_youngju.reset_index(drop=True)

# %%
facility_youngju[['매우 불만족 (%)','약간 불만족 (%)','보통 (%)','약간 만족 (%)','매우 만족 (%)','평균(5점) (점)']] = facility_youngju[['매우 불만족 (%)','약간 불만족 (%)','보통 (%)','약간 만족 (%)','매우 만족 (%)','평균(5점) (점)']].astype(float)

# %%
sex_youngju = facility_youngju.loc[facility_youngju['특성별(1)']=='성별']
age_youngju = facility_youngju.loc[facility_youngju['특성별(1)']=='연령별']
job_youngju = facility_youngju.loc[facility_youngju['특성별(1)']=='경제활동 상태별']
money_youngju = facility_youngju.loc[facility_youngju['특성별(1)']=='소득수준별']
edu_youngju = facility_youngju.loc[facility_youngju['특성별(1)']=='교육정도별']

# %%
facility_andong = df2[['특성별(1)', '특성별(2)', '문화여가시설(접근성과 충분정도)']]
facility_andong

# 첫 번째 행을 열 이름으로 설정하고 기존의 열 이름은 삭제
facility_andong.columns = facility_andong.iloc[0]
facility_andong = facility_andong.drop(0)

# 데이터프레임의 인덱스를 재설정 (기존 인덱스는 삭제)
facility_andong = facility_andong.reset_index(drop=True)

# %%
facility_andong[['매우 불만족 (%)','약간 불만족 (%)','보통 (%)','약간 만족 (%)','매우 만족 (%)','평균(5점) (점)']] = facility_andong[['매우 불만족 (%)','약간 불만족 (%)','보통 (%)','약간 만족 (%)','매우 만족 (%)','평균(5점) (점)']].astype(float)

# %%
sex_andong = facility_andong.loc[facility_andong['특성별(1)']=='성별']
age_andong = facility_andong.loc[facility_andong['특성별(1)']=='연령별']
job_andong = facility_andong.loc[facility_andong['특성별(1)']=='경제활동 상태별']
money_andong = facility_andong.loc[facility_andong['특성별(1)']=='소득수준별']
edu_andong = facility_andong.loc[facility_andong['특성별(1)']=='교육정도별']

# %%
sex_andong
# Out:
# 0 특성별(1) 특성별(2)  매우 불만족 (%)  약간 불만족 (%)  보통 (%)  약간 만족 (%)  매우 만족 (%)  \
# 1     성별     남자         7.1        23.8    56.1       11.4        1.5
# 2     성별     여자         6.0        25.7    57.2       10.6        0.5
#
# 0  평균(5점) (점)
# 1        2.76
# 2        2.74

# %%
sex_youngju
# Out:
# 0 특성별(1) 특성별(2)  매우 불만족 (%)  약간 불만족 (%)  보통 (%)  약간 만족 (%)  매우 만족 (%)  \
# 1     성별     남자         6.1        32.5    51.7        9.7        0.0
# 2     성별     여자         3.5        28.7    56.0       11.8        0.0
#
# 0  평균(5점) (점)
# 1        2.65
# 2        2.76

# %%
plt.rc('font', family='Malgun Gothic')
sns.set(font="Malgun Gothic",#"NanumGothicCoding", 
        rc={"axes.unicode_minus":False}, # 마이너스 부호 깨짐 현상 해결
        style='darkgrid')

# %%
# Andong 데이터프레임에서 성별에 따른 백분율 데이터 추출
andong_male = sex_andong.loc[sex_andong['특성별(2)'] == '남자'].iloc[0, 2:-1].astype(float)
andong_female = sex_andong.loc[sex_andong['특성별(2)'] == '여자'].iloc[0, 2:-1].astype(float)

# Youngju 데이터프레임에서 성별에 따른 백분율 데이터 추출
youngju_male = sex_youngju.loc[sex_youngju['특성별(2)'] == '남자'].iloc[0, 2:-1].astype(float)
youngju_female = sex_youngju.loc[sex_youngju['특성별(2)'] == '여자'].iloc[0, 2:-1].astype(float)

# 그래프에 사용할 항목들
categories = ['매우 불만족', '약간 불만족', '보통', '약간 만족', '매우 만족']
x = np.arange(len(categories))

# 그래프 설정
fig, ax = plt.subplots()
bar_width = 0.35

# 막대 그래프 그리기
bars1 = ax.barh(x - bar_width/2, andong_male, bar_width, label='Andong - Male')
bars2 = ax.barh(x + bar_width/2, youngju_male, bar_width, label='Youngju - Male')
bars3 = ax.barh(x - bar_width/2, andong_female, bar_width, left=andong_male, label='Andong - Female')
bars4 = ax.barh(x + bar_width/2, youngju_female, bar_width, left=youngju_male, label='Youngju - Female')

# 축 및 레이블 설정
ax.set_ylabel('응답 항목')
ax.set_xlabel('백분율')
ax.set_title('Andong vs. Youngju by Gender')
ax.set_yticks(x)
ax.set_yticklabels(categories)
ax.legend()

# 그리드 표시
ax.grid(True)

# 그래프 표시
plt.show()

# %%
# Andong 데이터프레임에서 성별에 따른 백분율 데이터 추출
andong_male = sex_andong.loc[sex_andong['특성별(2)'] == '남자'].iloc[0, 2:-1].astype(float)
andong_female = sex_andong.loc[sex_andong['특성별(2)'] == '여자'].iloc[0, 2:-1].astype(float)

# Youngju 데이터프레임에서 성별에 따른 백분율 데이터 추출
youngju_male = sex_youngju.loc[sex_youngju['특성별(2)'] == '남자'].iloc[0, 2:-1].astype(float)
youngju_female = sex_youngju.loc[sex_youngju['특성별(2)'] == '여자'].iloc[0, 2:-1].astype(float)
# 그래프에 사용할 항목들
categories = ['매우 불만족', '약간 불만족', '보통', '약간 만족', '매우 만족']
x = range(len(categories))

# 꺾은선 그래프 그리기
plt.plot(x, andong_male, marker='o', label='Andong - Male')
plt.plot(x, andong_female, marker='o', label='Andong - Female')
plt.plot(x, youngju_male, marker='o', label='Youngju - Male')
plt.plot(x, youngju_female, marker='o', label='Youngju - Female')

# 축 및 레이블 설정
plt.xlabel('응답 항목')
plt.ylabel('백분율')
plt.title('Andong vs. Youngju by Gender')
plt.xticks(x, categories)
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
# Andong 데이터프레임에서 성별에 따른 백분율 데이터 추출
andong_male = sex_andong.loc[sex_andong['특성별(2)'] == '남자'].iloc[0, 2:-1].astype(float)
andong_female = sex_andong.loc[sex_andong['특성별(2)'] == '여자'].iloc[0, 2:-1].astype(float)

# Youngju 데이터프레임에서 성별에 따른 백분율 데이터 추출
youngju_male = sex_youngju.loc[sex_youngju['특성별(2)'] == '남자'].iloc[0, 2:-1].astype(float)
youngju_female = sex_youngju.loc[sex_youngju['특성별(2)'] == '여자'].iloc[0, 2:-1].astype(float)
# Andong 데이터프레임에서 성별에 따른 백분율 데이터 추출
andong_male = sex_andong.loc[sex_andong['특성별(2)'] == '남자'].iloc[0, 2:-1].astype(float)
andong_female = sex_andong.loc[sex_andong['특성별(2)'] == '여자'].iloc[0, 2:-1].astype(float)

# Youngju 데이터프레임에서 성별에 따른 백분율 데이터 추출
youngju_male = sex_youngju.loc[sex_youngju['특성별(2)'] == '남자'].iloc[0, 2:-1].astype(float)
youngju_female = sex_youngju.loc[sex_youngju['특성별(2)'] == '여자'].iloc[0, 2:-1].astype(float)

# 그래프에 사용할 항목들
categories = ['매우 불만족', '약간 불만족', '보통', '약간 만족', '매우 만족']
x = np.arange(len(categories))

# 그래프 설정
fig, ax = plt.subplots(figsize=(10, 6))
bar_width = 0.2

# 안동 지역의 여자 데이터
bars1 = ax.bar(x - 1.5 * bar_width, andong_female, bar_width, label='안동-여자', color='b')
# 안동 지역의 남자 데이터
bars2 = ax.bar(x - 0.5 * bar_width, andong_male, bar_width, label='안동-남자', color='g')
# 영주 지역의 여자 데이터
bars3 = ax.bar(x + 0.5 * bar_width, youngju_female, bar_width, label='영주-여자', color='r')
# 영주 지역의 남자 데이터
bars4 = ax.bar(x + 1.5 * bar_width, youngju_male, bar_width, label='영주-남자', color='y')

# 축 및 레이블 설정
ax.set_xlabel('응답 항목')
ax.set_ylabel('백분율')
ax.set_title('안동시, 영주시 성별별 문화 만족도')
ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.legend()

# 그리드 표시
ax.grid(True)

# 그래프 표시
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Andong 데이터프레임에서 성별에 따른 백분율 데이터 추출
andong_male = sex_andong.loc[sex_andong['특성별(2)'] == '남자'].iloc[0, 2:-1].astype(float)
andong_female = sex_andong.loc[sex_andong['특성별(2)'] == '여자'].iloc[0, 2:-1].astype(float)

# Youngju 데이터프레임에서 성별에 따른 백분율 데이터 추출
youngju_male = sex_youngju.loc[sex_youngju['특성별(2)'] == '남자'].iloc[0, 2:-1].astype(float)
youngju_female = sex_youngju.loc[sex_youngju['특성별(2)'] == '여자'].iloc[0, 2:-1].astype(float)

# 그래프에 사용할 항목들
categories = ['매우 불만족', '약간 불만족', '보통', '약간 만족', '매우 만족']
x = np.arange(len(categories))

# 그래프 설정
fig, ax = plt.subplots()
bar_width = 0.35

# 막대 그래프 그리기
bars1 = ax.bar(x - bar_width/2, andong_male, bar_width, label='Andong - Male')
bars2 = ax.bar(x + bar_width/2, youngju_male, bar_width, label='Youngju - Male')
bars3 = ax.bar(x - bar_width/2, andong_female, bar_width, bottom=andong_male, label='Andong - Female')
bars4 = ax.bar(x + bar_width/2, youngju_female, bar_width, bottom=youngju_male, label='Youngju - Female')

# 축 및 레이블 설정
ax.set_xlabel('응답 항목')
ax.set_ylabel('백분율')
ax.set_title('Andong vs. Youngju by Gender')
ax.set_xticks(x)
ax.set_xticklabels(categories)
ax.legend()

# 그리드 표시
ax.grid(True)

# 그래프 표시
plt.show()

# %%
age_andong
# Out:
# 0 특성별(1)    특성별(2)  매우 불만족 (%)  약간 불만족 (%)  보통 (%)  약간 만족 (%)  매우 만족 (%)  \
# 3    연령별     29세이하         6.4        22.8    57.3       11.7        1.9
# 4    연령별  30 ~ 39세         9.4        26.4    41.6       22.6        0.0
# 5    연령별  40 ~ 49세         6.6        26.9    55.4       10.5        0.5
# 6    연령별  50 ~ 59세         4.7        20.6    60.7       12.5        1.5
# 7    연령별  60 ~ 69세         5.9        24.6    58.9        9.6        1.1
# 8    연령별     70세이상         7.5        27.8    58.9        5.0        0.7
#
# 0  평균(5점) (점)
# 3        2.80
# 4        2.77
# 5        2.71
# 6        2.85
# 7        2.75
# 8        2.64

# %%
age_youngju
# Out:
# 0 특성별(1)    특성별(2)  매우 불만족 (%)  약간 불만족 (%)  보통 (%)  약간 만족 (%)  매우 만족 (%)  \
# 3    연령별     29세이하         6.2        41.1    45.7        7.0        0.0
# 4    연령별  30 ~ 39세         7.7        30.3    45.9       16.1        0.0
# 5    연령별  40 ~ 49세         7.8        27.5    49.5       15.3        0.0
# 6    연령별  50 ~ 59세         4.9        29.4    57.0        8.7        0.0
# 7    연령별  60 ~ 69세         1.4        27.8    59.5       11.3        0.0
# 8    연령별     70세이상         3.9        29.5    57.3        9.3        0.0
#
# 0  평균(5점) (점)
# 3        2.53
# 4        2.70
# 5        2.72
# 6        2.69
# 7        2.81
# 8        2.72

# %%
age_andong = age_andong.drop(columns='특성별(1)')
age_youngju = age_youngju.drop(columns='특성별(1)')
age_youngju = age_youngju.drop(columns='평균(5점) (점)')
age_andong = age_andong.drop(columns='평균(5점) (점)')

# %%
age_andong
# Out:
# 0    특성별(2)  매우 불만족 (%)  약간 불만족 (%)  보통 (%)  약간 만족 (%)  매우 만족 (%)
# 3     29세이하         6.4        22.8    57.3       11.7        1.9
# 4  30 ~ 39세         9.4        26.4    41.6       22.6        0.0
# 5  40 ~ 49세         6.6        26.9    55.4       10.5        0.5
# 6  50 ~ 59세         4.7        20.6    60.7       12.5        1.5
# 7  60 ~ 69세         5.9        24.6    58.9        9.6        1.1
# 8     70세이상         7.5        27.8    58.9        5.0        0.7

# %%
age_youngju
# Out:
# 0    특성별(2)  매우 불만족 (%)  약간 불만족 (%)  보통 (%)  약간 만족 (%)  매우 만족 (%)
# 3     29세이하         6.2        41.1    45.7        7.0        0.0
# 4  30 ~ 39세         7.7        30.3    45.9       16.1        0.0
# 5  40 ~ 49세         7.8        27.5    49.5       15.3        0.0
# 6  50 ~ 59세         4.9        29.4    57.0        8.7        0.0
# 7  60 ~ 69세         1.4        27.8    59.5       11.3        0.0
# 8     70세이상         3.9        29.5    57.3        9.3        0.0

# %%
# Andong 데이터프레임에서 성별에 따른 백분율 데이터 추출
andong_29 = age_andong.loc[age_andong['특성별(2)'] == '29세이하']
andong_39 = age_andong.loc[age_andong['특성별(2)'] == '30 ~ 39세']
andong_49 = age_andong.loc[age_andong['특성별(2)'] == '40 ~ 49세']
andong_59 = age_andong.loc[age_andong['특성별(2)'] == '50 ~ 59세']
andong_69 = age_andong.loc[age_andong['특성별(2)'] == '60 ~ 69세']
andong_79 = age_andong.loc[age_andong['특성별(2)'] == '70세이상']

# Andong 데이터프레임에서 성별에 따른 백분율 데이터 추출
youngju_29 = age_youngju.loc[age_youngju['특성별(2)'] == '29세이하']
youngju_39 = age_youngju.loc[age_youngju['특성별(2)'] == '30 ~ 39세']
youngju_49 = age_youngju.loc[age_youngju['특성별(2)'] == '40 ~ 49세']
youngju_59 = age_youngju.loc[age_youngju['특성별(2)'] == '50 ~ 59세']
youngju_69 = age_youngju.loc[age_youngju['특성별(2)'] == '60 ~ 69세']
youngju_79 = age_youngju.loc[age_youngju['특성별(2)'] == '70세이상']

# %%
andong_79
# Out:
# 0 특성별(2)  매우 불만족 (%)  약간 불만족 (%)  보통 (%)  약간 만족 (%)  매우 만족 (%)
# 8  70세이상         7.5        27.8    58.9        5.0        0.7

# %%
# 그래프에 사용할 항목들
categories = ['매우 불만족', '약간 불만족', '보통', '약간 만족', '매우 만족']
x = len(categories)

# Assuming 'andong_29' and 'andong_39' are your DataFrames
dataframes_andong = [andong_29, andong_39, andong_49, andong_59, andong_69, andong_79]  # List of DataFrames
dataframes_youngju = [youngju_29, youngju_39, youngju_49, youngju_59, youngju_69, youngju_79]  # List of DataFrames

labels = ['29세이하', '30 ~ 39세','40 ~ 49세','50 ~ 59세','60 ~ 69세', '70세 이상' ]  # Labels for legend

plt.figure(figsize=(15, 10))
plt.subplot(2,1,1)
for df, label in zip(dataframes_andong, labels):
    # Extracting x and y data for plotting from DataFrame
    x_data = df.columns[1:]  # Exclude the first column which contains the index
    y_data = df.iloc[0][1:]  # Exclude the first element of the row which is the index value

    # Plotting
    plt.plot(x_data, y_data, marker='o', label=label)
    
plt.xlabel('만족도')
plt.ylabel('비율')
plt.title('연령대별 문화 만족도-안동시')
plt.legend()

plt.subplot(2,1,2)
for df, label in zip(dataframes_youngju, labels):
    # Extracting x and y data for plotting from DataFrame
    x_data = df.columns[1:]  # Exclude the first column which contains the index
    y_data = df.iloc[0][1:]  # Exclude the first element of the row which is the index value

    # Plotting
    plt.plot(x_data, y_data, marker='o', label=label)
plt.xlabel('만족도')
plt.ylabel('비율')
plt.title('연령대별 문화 만족도-영주시')
plt.legend()

# 그래프 표시
plt.tight_layout()  # 그래프 요소들이 겹치지 않도록 자동 조정
plt.savefig('연령대별 문화 만족도')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 그래프 설정
fig, ax = plt.subplots(figsize=(15, 8))
bar_width = 0.2

# Assuming 'andong_29' and 'andong_39' are your DataFrames
dataframes = [andong_29, andong_39, andong_49, andong_59, andong_69, andong_79]  # List of DataFrames
labels = ['29세이하', '30 ~ 39세', '40 ~ 49세', '50 ~ 59세', '60 ~ 69세', '70세 이상']  # Labels for legend

x = np.arange(len(categories)).astype(float)  # Convert to float data type

for df, label in zip(dataframes, labels):
    # Extracting y data for plotting from DataFrame
    y_data = df.iloc[0][1:]  # Exclude the first element of the row which is the index value

    # Plotting as a bar plot with spread-out bars
    ax.bar(x - 0.4 * bar_width, y_data, bar_width, label=label)

    # Update x positions for next group of bars
    x += bar_width * 0.7  # Adjust this factor as needed for spacing

# 축 및 레이블 설정
ax.set_xlabel('Satisfaction Level')
ax.set_ylabel('Percentage')
ax.set_title('Satisfaction Levels for Different Age Groups')
ax.set_xticks(np.arange(len(categories)))
ax.set_xticklabels(categories)
ax.legend()

    # 그래프 표시
plt.tight_layout()  # 그래프 요소들이 겹치지 않도록 자동 조정
# Show plot
plt.show()

# %% [markdown]
# ## 전반적인 여가활동

# %%
age_youngju
# Out:
# 0    특성별(2)  매우 불만족 (%)  약간 불만족 (%)  보통 (%)  약간 만족 (%)  매우 만족 (%)
# 3     29세이하         6.2        41.1    45.7        7.0        0.0
# 4  30 ~ 39세         7.7        30.3    45.9       16.1        0.0
# 5  40 ~ 49세         7.8        27.5    49.5       15.3        0.0
# 6  50 ~ 59세         4.9        29.4    57.0        8.7        0.0
# 7  60 ~ 69세         1.4        27.8    59.5       11.3        0.0
# 8     70세이상         3.9        29.5    57.3        9.3        0.0

# %%
free_youngju = df1[['특성별(1)', '특성별(2)', '전반적인 여가활동']]
free_youngju

# 첫 번째 행을 열 이름으로 설정하고 기존의 열 이름은 삭제
free_youngju.columns = free_youngju.iloc[0]
free_youngju = free_youngju.drop(0)

# # 데이터프레임의 인덱스를 재설정 (기존 인덱스는 삭제)
free_youngju = free_youngju.reset_index(drop=True)

# %%
free_youngju[['매우 불만족 (%)','약간 불만족 (%)','보통 (%)','약간 만족 (%)','매우 만족 (%)','평균(5점) (점)']] = free_youngju[['매우 불만족 (%)','약간 불만족 (%)','보통 (%)','약간 만족 (%)','매우 만족 (%)','평균(5점) (점)']].astype(float)

# %%
free_youngju
# Out:
# 0     특성별(1)        특성별(2)  매우 불만족 (%)  약간 불만족 (%)  보통 (%)  약간 만족 (%)  \
# 0         전체            소계         5.0        28.8    55.4       10.8
# 1         성별            남자         6.2        30.9    52.6       10.3
# 2         성별            여자         3.9        26.9    58.0       11.2
# 3        연령별         29세이하         7.4        33.9    54.0        4.7
# 4        연령별      30 ~ 39세         7.7        25.8    50.9       15.6
# 5        연령별      40 ~ 49세         7.8        24.6    53.7       14.0
# 6        연령별      50 ~ 59세         4.6        29.9    57.6        7.8
# 7        연령별      60 ~ 69세         1.0        28.4    56.4       14.3
# 8        연령별         70세이상         4.7        29.0    56.2       10.0
# 9   경제활동 상태별           취업자         4.7        28.5    54.6       12.2
# 10  경제활동 상태별         비경제활동         5.4        29.3    56.3        8.9
# 11     소득수준별      100만원 미만         4.3        30.5    63.2        1.9
# ...

# %%
free_andong = df2[['특성별(1)', '특성별(2)', '전반적인 여가활동']]

# 첫 번째 행을 열 이름으로 설정하고 기존의 열 이름은 삭제
free_andong.columns = free_andong.iloc[0]
free_andong = free_andong.drop(0)

# # 데이터프레임의 인덱스를 재설정 (기존 인덱스는 삭제)
free_andong = free_andong.reset_index(drop=True)

# %%
free_andong[['매우 불만족 (%)','약간 불만족 (%)','보통 (%)','약간 만족 (%)','매우 만족 (%)','평균(5점) (점)']] = free_andong[['매우 불만족 (%)','약간 불만족 (%)','보통 (%)','약간 만족 (%)','매우 만족 (%)','평균(5점) (점)']].astype(float)

# %%
free_andong
# Out:
# 0     특성별(1)        특성별(2)  매우 불만족 (%)  약간 불만족 (%)  보통 (%)  약간 만족 (%)  \
# 0         전체            소계         5.2        27.0    56.8       10.0
# 1         성별            남자         5.4        26.8    55.5       10.7
# 2         성별            여자         5.0        27.3    58.0        9.4
# 3        연령별         29세이하         3.6        23.9    60.7       10.4
# 4        연령별      30 ~ 39세         9.4        31.6    38.1       20.9
# 5        연령별      40 ~ 49세         5.4        29.1    57.2        7.9
# 6        연령별      50 ~ 59세         3.1        23.0    61.0       11.5
# 7        연령별      60 ~ 69세         4.5        27.0    58.1        9.1
# 8        연령별         70세이상         6.8        29.4    58.0        5.3
# 9   경제활동 상태별           취업자         3.5        27.1    56.3       11.8
# 10  경제활동 상태별         비경제활동         7.7        27.0    57.6        7.3
# 11     소득수준별      100만원 미만         8.1        31.7    55.6        4.6
# ...

# %%
free_age_andong = free_andong.loc[free_andong['특성별(1)']=='연령별']
free_age_youngju = free_youngju.loc[free_andong['특성별(1)'] == '연령별']

# %%
free_age_andong = free_age_andong.drop(columns=['특성별(1)', '평균(5점) (점)'])
free_age_youngju = free_age_youngju.drop(columns=['특성별(1)', '평균(5점) (점)'])

# %%
# Andong 데이터프레임에서 성별에 따른 백분율 데이터 추출
free_andong_29 = free_age_andong.loc[free_age_andong['특성별(2)'] == '29세이하']
free_andong_39 = free_age_andong.loc[free_age_andong['특성별(2)'] == '30 ~ 39세']
free_andong_49 = free_age_andong.loc[free_age_andong['특성별(2)'] == '40 ~ 49세']
free_andong_59 = free_age_andong.loc[free_age_andong['특성별(2)'] == '50 ~ 59세']
free_andong_69 = free_age_andong.loc[free_age_andong['특성별(2)'] == '60 ~ 69세']
free_andong_79 = free_age_andong.loc[free_age_andong['특성별(2)'] == '70세이상']

# Andong 데이터프레임에서 성별에 따른 백분율 데이터 추출
free_youngju_29 = free_age_youngju.loc[free_age_youngju['특성별(2)'] == '29세이하']
free_youngju_39 = free_age_youngju.loc[free_age_youngju['특성별(2)'] == '30 ~ 39세']
free_youngju_49 = free_age_youngju.loc[free_age_youngju['특성별(2)'] == '40 ~ 49세']
free_youngju_59 = free_age_youngju.loc[free_age_youngju['특성별(2)'] == '50 ~ 59세']
free_youngju_69 = free_age_youngju.loc[free_age_youngju['특성별(2)'] == '60 ~ 69세']
free_youngju_79 = free_age_youngju.loc[free_age_youngju['특성별(2)'] == '70세이상']

# %%
free_andong_79
# Out:
# 0 특성별(2)  매우 불만족 (%)  약간 불만족 (%)  보통 (%)  약간 만족 (%)  매우 만족 (%)
# 8  70세이상         6.8        29.4    58.0        5.3        0.6

# %%
# 그래프에 사용할 항목들
categories = ['매우 불만족', '약간 불만족', '보통', '약간 만족', '매우 만족']
x = len(categories)

# Assuming 'andong_29' and 'andong_39' are your DataFrames
dataframes_andong = [free_andong_29, free_andong_39, free_andong_49, free_andong_59, free_andong_69, free_andong_79]  # List of DataFrames
dataframes_youngju = [free_youngju_29, free_youngju_39, free_youngju_49, free_youngju_59, free_youngju_69, free_youngju_79]  # List of DataFrames

labels = ['29세이하', '30 ~ 39세','40 ~ 49세','50 ~ 59세','60 ~ 69세', '70세 이상' ]  # Labels for legend

plt.figure(figsize=(15, 10))
plt.subplot(2,1,1)
for df, label in zip(dataframes_andong, labels):
    # Extracting x and y data for plotting from DataFrame
    x_data = df.columns[1:]  # Exclude the first column which contains the index
    y_data = df.iloc[0][1:]  # Exclude the first element of the row which is the index value

    # Plotting
    plt.plot(x_data, y_data, marker='o', label=label)
    
plt.xlabel('만족도')
plt.ylabel('비율')
plt.title('전반적인 여가활동 만족도 - 안동시')
plt.legend()

plt.subplot(2,1,2)
for df, label in zip(dataframes_youngju, labels):
    # Extracting x and y data for plotting from DataFrame
    x_data = df.columns[1:]  # Exclude the first column which contains the index
    y_data = df.iloc[0][1:]  # Exclude the first element of the row which is the index value

    # Plotting
    plt.plot(x_data, y_data, marker='o', label=label)
plt.xlabel('만족도')
plt.ylabel('비율')
plt.title('전반적인 여가활동 만족도 - 영주시')
plt.legend()

# 그래프 표시
plt.tight_layout()  # 그래프 요소들이 겹치지 않도록 자동 조정
plt.savefig('전반적인 여가활동 만족도')
plt.show()

# %%
unsatisfied_youngju = df1[['특성별(1)', '특성별(2)', '불만족 이유 (%)']]

# 첫 번째 행을 열 이름으로 설정하고 기존의 열 이름은 삭제
unsatisfied_youngju.columns = unsatisfied_youngju.iloc[0]
unsatisfied_youngju = unsatisfied_youngju.drop(0)

# # 데이터프레임의 인덱스를 재설정 (기존 인덱스는 삭제)
unsatisfied_youngju = unsatisfied_youngju.reset_index(drop=True)

# %%
unsatisfied_andong = df2[['특성별(1)', '특성별(2)', '불만족 이유 (%)']]

# 첫 번째 행을 열 이름으로 설정하고 기존의 열 이름은 삭제
unsatisfied_andong.columns = unsatisfied_andong.iloc[0]
unsatisfied_andong = unsatisfied_andong.drop(0)

# # 데이터프레임의 인덱스를 재설정 (기존 인덱스는 삭제)
unsatisfied_andong = unsatisfied_andong.reset_index(drop=True)

# %%
unsatisfied_youngju[['경제적 부담 때문에', '시간이 부족하여', '교통혼잡 및 이용 교통수단이 불편해서', '여가시설이 부족하여', '여가 정보 및 프로그램이 부족하여', '적당한 취미가 없어서','체력이나 건강이 좋지 않아서', '여가를 함께 즐길 사람이 없어서', '기타']] = unsatisfied_youngju[['경제적 부담 때문에', '시간이 부족하여', '교통혼잡 및 이용 교통수단이 불편해서', '여가시설이 부족하여', '여가 정보 및 프로그램이 부족하여', '적당한 취미가 없어서','체력이나 건강이 좋지 않아서', '여가를 함께 즐길 사람이 없어서', '기타']].astype(float)
unsatisfied_andong[['경제적 부담 때문에', '시간이 부족하여', '교통혼잡 및 이용 교통수단이 불편해서', '여가시설이 부족하여', '여가 정보 및 프로그램이 부족하여', '적당한 취미가 없어서','체력이나 건강이 좋지 않아서', '여가를 함께 즐길 사람이 없어서', '기타']] = unsatisfied_andong[['경제적 부담 때문에', '시간이 부족하여', '교통혼잡 및 이용 교통수단이 불편해서', '여가시설이 부족하여', '여가 정보 및 프로그램이 부족하여', '적당한 취미가 없어서','체력이나 건강이 좋지 않아서', '여가를 함께 즐길 사람이 없어서', '기타']].astype(float)

# %%
unsatisfied_age_andong = unsatisfied_andong.loc[unsatisfied_andong['특성별(1)']=='연령별']
unsatisfied_age_youngju = unsatisfied_youngju.loc[unsatisfied_andong['특성별(1)'] == '연령별']

# %%
unsatisfied_age_andong
# Out:
# 0 특성별(1)    특성별(2)  경제적 부담 때문에  시간이 부족하여  교통혼잡 및 이용 교통수단이 불편해서  여가시설이 부족하여  \
# 3    연령별     29세이하        24.9      12.0                   2.7        32.2
# 4    연령별  30 ~ 39세        22.9      18.9                   3.9        22.1
# 5    연령별  40 ~ 49세        16.6      36.1                   4.8        13.3
# 6    연령별  50 ~ 59세        33.2      15.8                   7.3        18.6
# 7    연령별  60 ~ 69세        23.1      21.6                   6.8        17.5
# 8    연령별     70세이상        20.7       5.3                  10.7         8.9
#
# 0  여가 정보 및 프로그램이 부족하여  적당한 취미가 없어서  체력이나 건강이 좋지 않아서  여가를 함께 즐길 사람이 없어서   기타
# 3                23.3          2.3              2.7                0.0  0.0
# 4                18.9          3.9              3.9                0.0  5.3
# 5                18.1          2.8              3.6                3.2  1.6
# 6                12.1          5.2              5.8                0.9  1.2
# ...

# %%
unsatisfied_age_andong = unsatisfied_age_andong.drop(columns=['특성별(1)'])
unsatisfied_age_youngju = unsatisfied_age_youngju.drop(columns=['특성별(1)'])

# %%
unsatisfied_age_andong
# Out:
# 0    특성별(2)  경제적 부담 때문에  시간이 부족하여  교통혼잡 및 이용 교통수단이 불편해서  여가시설이 부족하여  \
# 3     29세이하        24.9      12.0                   2.7        32.2
# 4  30 ~ 39세        22.9      18.9                   3.9        22.1
# 5  40 ~ 49세        16.6      36.1                   4.8        13.3
# 6  50 ~ 59세        33.2      15.8                   7.3        18.6
# 7  60 ~ 69세        23.1      21.6                   6.8        17.5
# 8     70세이상        20.7       5.3                  10.7         8.9
#
# 0  여가 정보 및 프로그램이 부족하여  적당한 취미가 없어서  체력이나 건강이 좋지 않아서  여가를 함께 즐길 사람이 없어서   기타
# 3                23.3          2.3              2.7                0.0  0.0
# 4                18.9          3.9              3.9                0.0  5.3
# 5                18.1          2.8              3.6                3.2  1.6
# 6                12.1          5.2              5.8                0.9  1.2
# 7                 9.2          4.6             14.2                3.0  0.0
# ...

# %%
# Andong 데이터프레임에서 성별에 따른 백분율 데이터 추출
un_andong_29 = unsatisfied_age_andong.loc[unsatisfied_age_andong['특성별(2)'] == '29세이하']
un_andong_39 = unsatisfied_age_andong.loc[unsatisfied_age_andong['특성별(2)'] == '30 ~ 39세']
un_andong_49 = unsatisfied_age_andong.loc[unsatisfied_age_andong['특성별(2)'] == '40 ~ 49세']
un_andong_59 = unsatisfied_age_andong.loc[unsatisfied_age_andong['특성별(2)'] == '50 ~ 59세']
un_andong_69 = unsatisfied_age_andong.loc[free_age_andong['특성별(2)'] == '60 ~ 69세']
un_andong_79 = unsatisfied_age_andong.loc[free_age_andong['특성별(2)'] == '70세이상']

# Andong 데이터프레임에서 성별에 따른 백분율 데이터 추출
un_youngju_29 = unsatisfied_age_youngju.loc[unsatisfied_age_youngju['특성별(2)'] == '29세이하']
un_youngju_39 = unsatisfied_age_youngju.loc[unsatisfied_age_youngju['특성별(2)'] == '30 ~ 39세']
un_youngju_49 = unsatisfied_age_youngju.loc[unsatisfied_age_youngju['특성별(2)'] == '40 ~ 49세']
un_youngju_59 = unsatisfied_age_youngju.loc[unsatisfied_age_youngju['특성별(2)'] == '50 ~ 59세']
un_youngju_69 = unsatisfied_age_youngju.loc[unsatisfied_age_youngju['특성별(2)'] == '60 ~ 69세']
un_youngju_79 = unsatisfied_age_youngju.loc[unsatisfied_age_youngju['특성별(2)'] == '70세이상']

# %%
# 그래프에 사용할 항목들
categories = ['경제적 부담 때문에', '시간이 부족하여', '교통혼잡 및 이용 교통수단이 불편해서', '여가시설이 부족하여', '여가 정보 및 프로그램이 부족하여', '적당한 취미가 없어서','체력이나 건강이 좋지 않아서', '여가를 함께 즐길 사람이 없어서', '기타']
x = len(categories)

# Assuming 'andong_29' and 'andong_39' are your DataFrames
dataframes_andong = [un_andong_29, un_andong_39, un_andong_49, un_andong_59, un_andong_69, un_andong_79]  # List of DataFrames
dataframes_youngju = [un_youngju_29, un_youngju_39, un_youngju_49, un_youngju_59, un_youngju_69, un_youngju_79]  # List of DataFrames

labels = ['29세이하', '30 ~ 39세','40 ~ 49세','50 ~ 59세','60 ~ 69세', '70세 이상' ]  # Labels for legend

plt.figure(figsize=(15, 10))
plt.subplot(2,1,1)
for df, label in zip(dataframes_andong, labels):
    # Extracting x and y data for plotting from DataFrame
    x_data = df.columns[1:]  # Exclude the first column which contains the index
    y_data = df.iloc[0][1:]  # Exclude the first element of the row which is the index value

    # Plotting
    plt.plot(x_data, y_data, marker='o', label=label)
    
plt.xlabel('만족도')
plt.ylabel('비율')
plt.title('불만족 이유 - 안동시')
plt.xticks(rotation=10)
plt.legend()

plt.subplot(2,1,2)
for df, label in zip(dataframes_youngju, labels):
    # Extracting x and y data for plotting from DataFrame
    x_data = df.columns[1:]  # Exclude the first column which contains the index
    y_data = df.iloc[0][1:]  # Exclude the first element of the row which is the index value

    # Plotting
    plt.plot(x_data, y_data, marker='o', label=label)
plt.xlabel('만족도')
plt.ylabel('비율')
plt.title('불만족 이유 - 영주시')
plt.legend()
plt.xticks(rotation=10)

# 그래프 표시
plt.tight_layout()  # 그래프 요소들이 겹치지 않도록 자동 조정
plt.savefig('ㅂ')
plt.show()
