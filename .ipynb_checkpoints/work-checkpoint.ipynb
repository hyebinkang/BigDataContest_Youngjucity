# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('삶에_대한_만족감과_정서경험_2021.csv', encoding='cp949')
df2 = pd.read_csv('일자리충분도_2021.csv', encoding='cp949')

# %%
# 첫 번째 행을 열 이름으로 설정하고 기존의 열 이름은 삭제
df1.columns = df1.iloc[0]
df1 = df1.drop(0)

# 데이터프레임의 인덱스를 재설정 (기존 인덱스는 삭제)
df1 = df1.reset_index(drop=True)

# %%
cols = ['살고있는 지역의 전반적 만족감', '어제 행복 정도','어제 걱정 정도']
df1.drop(columns=cols, axis=1, inplace = True)

# %%
df1 = df1.loc[df1['특성별(1)']=='연령별']
df1.drop(columns='특성별(1)', axis=1, inplace=True)

# %%
df1
# Out:
# 0    특성별(2) 삶에 대한 전반적 만족감
# 3    29세 이하          5.72
# 4  30 ~ 39세          6.26
# 5  40 ~ 49세          6.09
# 6  50 ~ 59세          5.88
# 7  60 ~ 69세          5.73
# 8    70세 이상          5.38

# %%
# 첫 번째 행을 열 이름으로 설정하고 기존의 열 이름은 삭제
df2.columns = df2.iloc[0]
df2 = df2.drop(0)

# 데이터프레임의 인덱스를 재설정 (기존 인덱스는 삭제)
df2 = df2.reset_index(drop=True)

# %%
df2
# Out:
# 0  특성별(1)        특성별(2) 전혀 그렇지 않다 그렇지 않은 편이다  보통이다 그런 편이다 매우 그렇다
# 0      전체            소계      11.6       49.9  30.0    8.0    0.5
# 1      성별            남자      10.8       50.3  30.9    7.9    0.1
# 2      성별            여자      12.5       49.6  29.1    8.0    0.8
# 3     연령별        29세 이하      22.3       50.5  21.8    5.3    0.0
# 4     연령별      30 ~ 39세      14.9       52.4  20.2   12.5    0.0
# 5     연령별      40 ~ 49세      17.1       46.2  25.7   10.5    0.5
# 6     연령별      50 ~ 59세       8.1       52.9  30.7    7.4    1.0
# 7     연령별      60 ~ 69세       6.6       49.5  37.8    5.9    0.3
# 8     연령별        70세 이상       7.1       49.0  34.6    8.7    0.7
# 9   경제활동별           취업자       9.7       48.3  33.4    8.4    0.2
# 10  경제활동별         비경제활동      14.0       51.9  25.9    7.4    0.8
# 11  가구소득별      100만원 미만       7.0       53.3  34.8    4.4    0.5
# 12  가구소득별  100~200만원 미만      13.7       46.0  33.1    6.5    0.7
# ...

# %% [markdown]
# ### 단순 시각화
# - 일자리 충분도

# %%
df3 = pd.read_csv('취업자_근로여건_만족도_2022.csv', encoding='cp949')

# %%
df3
# Out:
#       특성별(1)        특성별(2)        2022      2022.1  2022.2     2022.3  \
# 0     특성별(1)        특성별(2)         하는일         하는일     하는일        하는일
# 1     특성별(1)        특성별(2)  매우 불만족 (%)  약간 불만족 (%)  보통 (%)  약간 만족 (%)
# 2         전체            소계         0.4        14.7    38.2       44.6
# 3         성별            남자         0.0        16.0    33.6       48.3
# 4         성별            여자         1.0        12.8    45.1       39.1
# 5        연령별         29세이하         0.0        20.0    49.9       30.0
# 6        연령별      30 ~ 39세         0.0         9.4    31.4       59.2
# 7        연령별      40 ~ 49세         0.0        11.2    32.0       53.1
# 8        연령별      50 ~ 59세         0.7        16.1    41.3       37.8
# 9        연령별      60 ~ 69세         0.0        24.5    36.2       39.3
# 10       연령별         70세이상         3.7         9.4    54.6       32.2
# 11  경제활동 상태별           취업자         0.4        14.7    38.2       44.6
# ...

# %%
# 첫 번째 행을 열 이름으로 설정하고 기존의 열 이름은 삭제
df3.columns = df3.iloc[0]
df3 = df3.drop(0)

# 데이터프레임의 인덱스를 재설정 (기존 인덱스는 삭제)
df3 = df3.reset_index(drop=True)
df3 = df3.loc[df3['특성별(1)']=='연령별']

# %%
df3.drop(columns='특성별(1)', axis=1, inplace=True)

# %%
df3 = df3.set_index('특성별(2)')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 df3 = df3.set_index('특성별(2)')
#       2 df3
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5859, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5856                 missing.append(col)
#    5858 if missing:
# -> 5859     raise KeyError(f"None of {missing} are in the columns")
#    5861 if inplace:
#    5862     frame = self
#
# KeyError: "None of ['특성별(2)'] are in the columns"

# %%
df3_work =
# Out:
# 0         하는일   하는일   하는일   하는일  하는일   하는일 임금/가구소득(일에 비해) 임금/가구소득(일에 비해)  \
# 특성별(2)
# 29세이하     0.0  20.0  49.9  30.0  0.0  3.10            0.0           40.0
# 30 ~ 39세  0.0   9.4  31.4  59.2  0.0  3.50            1.7           11.1
# 40 ~ 49세  0.0  11.2  32.0  53.1  3.7  3.49            2.5           17.4
# 50 ~ 59세  0.7  16.1  41.3  37.8  4.1  3.28            1.8           20.4
# 60 ~ 69세  0.0  24.5  36.2  39.3  0.0  3.15            2.6           32.4
# 70세이상     3.7   9.4  54.6  32.2  0.0  3.15            7.4           26.0
#
# 0        임금/가구소득(일에 비해) 임금/가구소득(일에 비해)  ...  근무환경  근무환경 근무환경  근무환경 전반적인 만족도  \
# 특성별(2)                                  ...
# 29세이하              44.6           15.4  ...  47.2  35.0  0.0  3.17      0.0
# 30 ~ 39세           34.2           50.4  ...  43.5  38.5  0.0  3.21      0.0
# 40 ~ 49세           39.6           38.2  ...  40.9  40.0  3.4  3.26      0.0
# 50 ~ 59세           38.9           36.9  ...  36.7  24.9  3.0  2.91      0.7
# ...
